# %%
# As Respostas do Exercicio Encontram-se No Final Deste Documento.


# libraries
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import seaborn as sns
sns.set_style("white")
import pandas as pd
my_dpi=96

# %%
# Get the data (csv file is hosted on the web)
url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'
data = pd.read_csv(url)
#data=pd.read_csv('gapminderData.csv')
data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
# And I need to transform my categorical column (continent) in a numerical value group1->1, group2->2...
data['continent']=pd.Categorical(data['continent'])

# %%
anos=data.year.unique()

# %%
# %matplotlib notebook
# %matplotlib notebook

# initialize a figure
#fig=plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)
fig, ax = plt.subplots(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)

# Add titles (main and on axis)
plt.yscale('log')
plt.xlabel("Life Expectancy")
plt.ylabel("GDP per Capita")
plt.ylim(100,100000)
plt.xlim(30, 90)

def animate(i):
    plt.title("Year: "+str(anos[i]) )
    tmp=data[ data.year == anos[i] ]
    scut=plt.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
    #scut=ax.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
    
    ###>_________________________________________________________________________________________________________________________
    ###>Inserir uma legenda ou legendas com a cor das “bolhas”
    ###>e o seu significado, posicionada(s) em área(s) que não
    ###>se sobreponha(m) às “bolhas”. Fundamente asopções tomadas.
    ###>
   
    Legenda_Continentes= ax.legend(labels = data["continent"].unique(), handles =scut.legend_elements () [0], loc=4, title= "Continente")  
    
    ###
    ###>________________________________________________________________________________________________________________________
    
    

ani = animation.FuncAnimation(fig, animate, frames=len(anos), interval=200, blit=False, repeat=False)
    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="680">

# %% [markdown]
# **Questão A: – Explique a metodologia para criar a animação em cada um dos casos
# (versões). Comente-as. Justifique.**

# %% [markdown]
# 1º - importar as bibliotecas, pandas/matplotlib/numpy/seaborn tambem é definedo a cor de fundo e tamanho da figura com my_dpi=96.
# 2º - com o url permitiu o acesso dos dados a um site ou plataforma para o programa ler estes dados. A tabela apresenta uma coluna com o nome do país, no qual indica "country", seguido de outras colunas ("year", "pop", "continent", "lifeExp", "gdpPercap").
# 3º - A cada Continente (situado na coluna "continente"), foi-lhe atribuído um grupo e um respetivo número.
# 4º - Depois é atribuido os dados da coluna year na variavel anos.
# 5º - Foi definido o tamanho da figura com 680x480 dpi.
#      Nas linhas seguintes definiu-se uma escala atribuindo ao eixo de X "Life Expectancy", e o Y "GDP per Capita".
#      O programador definiu os limite de cada eixo: (y) - vai desde do 100 até 100000; (x) - vai desde 30 a 90 anos.
#      Foi definido uma função que carateriza a formação de cada imagem.
#      A animação é representada com o codigo ani = animation.FuncAnimation(fig, animate, frames=len(anos), interval=200, blit=False, repeat=False)
#      Definindo que o número de frames da animação é referente ao número de anos que existem, dados pela variavel "anos", com o intervalo em cada frame de 200s, não permintindo a repetição da animação.
#      No final do codigo é pededido para iniciar animação.

# %% [markdown]
# **Questão B:– Temos “bolhas” de cinco (5) cores diferentes. O que representa cada
# cor? Justifique, com descrição detalhada do processo.**

# %% [markdown]
# Nas "bolhas", a cada cor está atribuido um continente. As cores são definidas pela correspondencia do marcador que faz a cor ter uma caracterização por cada continente (0 = Asia ; 1 = Europa ; 2 = Africa ; 3 = Americas ; 4 = Oceania).
# Tudo isto acontece porque cada continente passa a ter a sua própia caracterização, e isto faz com que assim exista uma destinção através do codigo para a animação, onde seguidamente o marcador é definido, "c=tmp['continent'].cat.codes" o que agrupa por continente todas as bolhas com cor iguias.

# %% [markdown]
# **Questão C:– Inserir uma legenda ou legendas com a cor das “bolhas” e o seu
# significado, posicionada(s) em área(s) que não se sobreponha(m) às “bolhas”. Fundamente as
# opções tomadas.**

# %% [markdown]
# Em cima encontra-se aplicado o codigo para legenda, as cores utilizadas são as mesmas que as utilizadas nasw
# bolhas, a legenda é referente aos diferentes continentes, ao usarmos o " loc=4  definimos que a legenda fica no
# canto inferiror direito, ao usarmos o  "handles" faz com que a legenda distinga os dados representados.
# Foi acrescentado um titulo à legenda com o nome de "Continente".
